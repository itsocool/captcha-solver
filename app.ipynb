# %%
# !uv add ollama

# %%
from ollama import chat, ChatResponse
import os

model_id = 'qwen3-vl:235b-instruct-cloud'
api_key = 'f306bbcebc3642f39e43744afa3c13b7.aH1Gn9Al9C-LvxKczozDTU8s'

os.environ['OLLAMA_API_KEY'] = api_key
os.environ.setdefault('OLLAMA_HOST', 'https://ollama.com/api')
print('OLLAMA_HOST=', os.environ['OLLAMA_HOST'])

try:
    response: ChatResponse = chat(
        model=model_id,
        messages=[{'role': 'user', 'content': '삼국지 인물중 조운의 고향은 현재 중국의 어디인가?'}],
        options={'temperature': 0.0},
    )
    print('Client response:', response.message.content)
except Exception as e:
    print('Client call failed:', e)

# %%
import ollama_generate
import os

OLLAMA_HOST = os.getenv('OLLAMA_HOST', 'https://ollama.com/api')
os.environ.setdefault('OLLAMA_HOST', 'https://ollama.com/api')
OLLAMA_MODEL_ID = os.getenv("OLLAMA_MODEL_ID", "qwen3-vl:235b-instruct-cloud")
OLLAMA_API_KEY = os.getenv("OLLAMA_API_KEY", "f306bbcebc3642f39e43744afa3c13b7.aH1Gn9Al9C-LvxKczozDTU8s")

print('OLLAMA_HOST=', OLLAMA_HOST)

pred_dir = os.path.abspath(os.path.join('captcha_data', 'gov24', '1', 'images', 'pred'))
if not os.path.isdir(pred_dir):
    raise FileNotFoundError(f'Prediction directory not found: {pred_dir}')
files = [f for f in os.listdir(pred_dir) if os.path.isfile(os.path.join(pred_dir, f))]
if not files:
    raise FileNotFoundError(f'No files found in prediction directory: {pred_dir}')
image_path = os.path.join(pred_dir, files[0])
with open(image_path, 'rb') as fh:
    sample_bytes = fh.read()
print('Using file for test:', image_path)

result = ollama_generate.ocr_image(image_path=image_path)
file_name = os.path.basename(image_path)
# print('file_name  :', file_name)
# print('ocr_result :', result)
result
# Out:
# OLLAMA_HOST= https://ollama.com/api
# Using file for test: /home/hyper/project/hyper-captcha-resolver/captcha_data/gov24/1/images/pred/680179.png
# image_path: /home/hyper/project/hyper-captcha-resolver/captcha_data/gov24/1/images/pred/680179.png
# OLLAMA_HOST= https://ollama.com/api
# response= model='qwen3-vl:235b-instruct' created_at='2025-11-08T12:20:57.675997711Z' done=True done_reason='stop' total_duration=1245436767 load_duration=None prompt_eval_count=189 prompt_eval_duration=None eval_count=48 eval_duration=None message=Message(role='assistant', content='{\n    "text": "680179",\n    "confidence": 0.98,\n    "bbox": [30, 100, 800, 600]\n}', thinking=None, images=None, tool_name=None, tool_calls=None)
# result : {
#     "text": "680179",
#     "confidence": 0.98,
#     "bbox": [30, 100, 800, 600]
# }
# {'text': '680179',
#  'confidence': 0.98,
#  'processing_ms': 6770,
#  'bbox': [30, 100, 800, 600]}

# %%
import os
from ollama import Client

client = Client(
    host="https://ollama.com",
    headers={'Authorization': 'Bearer ' + os.environ.get('OLLAMA_API_KEY')}
)

messages = [
  {
    'role': 'user',
    'content': 'Why is the sky blue?',
  },
]

for part in client.chat('qwen3-vl:235b-instruct-cloud', messages=messages, stream=True):
  print(part['message']['content'], end='', flush=True)
# Out:
# The sky appears blue due to a phenomenon called **Rayleigh scattering**.
#
# Here’s how it works:
#
# 1. **Sunlight is white** — it contains all the colors of the visible spectrum (red, orange, yellow, green, blue, indigo, violet).
#
# 2. **Earth’s atmosphere** is made up of gases and tiny particles. When sunlight enters the atmosphere, it collides with molecules (mostly nitrogen and oxygen) and scatters in all directions.
#
# 3. **Shorter wavelengths scatter more** — Blue light has a shorter wavelength (around 450–495 nanometers) than other colors like red or yellow. According to **Rayleigh scattering**, the amount of scattering is inversely proportional to the fourth power of the wavelength. That means blue light scatters about 10 times more than red light.
#
# 4. **Blue light fills the sky** — Because blue light is scattered in all directions by the atmosphere, it reaches our eyes from every part of the sky — not just directly from the sun. That’s why the entire sky appears blue during the day.
#
# ### Why not violet?
# Violet light has an even shorter wavelength than blue and scatters even more — but our eyes are less sensitive to violet, and the sun emits less violet light than blue. Also, some violet light is absorbed by the upper atmosphere. So we perceive the sky as blue, not violet.
#
# ### Bonus: Why sunsets are red/orange
# At sunset, sunlight travels through more atmosphere. Most of the blue light is scattered away before reaching us, leaving the longer wavelengths (red, orange) to dominate — hence the warm colors of sunset.
#
# So, in short: **The sky is blue because molecules in the atmosphere scatter short-wavelength blue light more than other colors — and that scattered blue light reaches our eyes from all directions.** 🌞💙
