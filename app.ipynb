# %%
from ollama import chat, ChatResponse
import os

model_id = 'qwen3-vl:235b-instruct-cloud'
api_key = 'f306bbcebc3642f39e43744afa3c13b7.aH1Gn9Al9C-LvxKczozDTU8s'

os.environ['OLLAMA_API_KEY'] = api_key
os.environ.setdefault('OLLAMA_HOST', 'https://ollama.com/api')
print('OLLAMA_HOST=', os.environ['OLLAMA_HOST'])

try:
    response: ChatResponse = chat(
        model=model_id,
        messages=[{'role': 'user', 'content': '삼국지 인물중 조운의 고향은 현재 중국의 어디인가?'}],
        options={'temperature': 0.0},
    )
    print('Client response:', response.message.content)
except Exception as e:
    print('Client call failed:', e)

# %%
import ollama_generate
import os

model_id = 'qwen3-vl:235b-instruct-cloud'
api_key = 'f306bbcebc3642f39e43744afa3c13b7.aH1Gn9Al9C-LvxKczozDTU8s'

os.environ['OLLAMA_API_KEY'] = api_key
os.environ.setdefault('OLLAMA_HOST', 'https://ollama.com/api')
print('OLLAMA_HOST=', os.environ['OLLAMA_HOST'])

pred_dir = os.path.abspath(os.path.join('captcha_data', 'gov24', '1', 'images', 'pred'))
if not os.path.isdir(pred_dir):
    raise FileNotFoundError(f'Prediction directory not found: {pred_dir}')
files = [f for f in os.listdir(pred_dir) if os.path.isfile(os.path.join(pred_dir, f))]
if not files:
    raise FileNotFoundError(f'No files found in prediction directory: {pred_dir}')
file_path = os.path.join(pred_dir, files[0])
with open(file_path, 'rb') as fh:
    sample_bytes = fh.read()
print('Using file for test:', file_path)

result = ollama_generate.ocr_image(image_path=file_path, model_id=model_id, api_key=api_key)
file_name = os.path.basename(file_path)
print('file_name  :', file_name)

content = result.message.content
print('ocr_result :', content)

result
# Out:
# OLLAMA_HOST= https://ollama.com/api
# Using file for test: /home/hyper/project/hyper-captcha-resolver/captcha_data/gov24/1/images/pred/415849.png
# file_name  : 415849.png
# ocr_result : 415849
# file_name  : 415849.png
# ocr_result : 415849
# ChatResponse(model='qwen3-vl:235b-instruct-cloud', created_at='2025-11-05T08:32:32.373102944Z', done=True, done_reason='stop', total_duration=711400291, load_duration=None, prompt_eval_count=137, prompt_eval_duration=None, eval_count=7, eval_duration=None, message=Message(role='assistant', content='415849', thinking=None, images=None, tool_name=None, tool_calls=None))

# %%
import ollama_generate
import os

model_id = 'qwen3-vl:235b-instruct-cloud'
api_key = 'f306bbcebc3642f39e43744afa3c13b7.aH1Gn9Al9C-LvxKczozDTU8s'

os.environ['OLLAMA_API_KEY'] = api_key
os.environ.setdefault('OLLAMA_HOST', 'https://ollama.com/api')
print('OLLAMA_HOST=', os.environ['OLLAMA_HOST'])

message = '삼국지 인물중 조운의 고향은 현재 중국의 어디인가?'
result = ollama_generate.cloud_chat(message=message, model_id=model_id, api_key=api_key)
print('Q : ', message)
content = result.message.content
print('A : ', content)

result
# Out:
# OLLAMA_HOST= https://ollama.com/api
# Q :  삼국지 인물중 조운의 고향은 현재 중국의 어디인가?
# A :  조운(趙雲, 조운)의 고향은 **현재 중국 허베이성 정딩현**(河北省 正定縣)입니다.
#
# ### 상세 설명:
#
# - **조운**은 삼국지 시대 촉한의 유명한 장군으로, ‘자룡(子龍)’이라는 자를 쓰며, 충성과 용맹, 정의로운 성격으로 유명합니다.
# - 그의 고향은 **상당군 진정현**(常山郡 真定縣)으로, **한나라 시대**에 속한 지역입니다.
# - 이 지역은 현재 **중국 허베이성 정딩현**(正定縣, Hebei Province, Zhengding County)으로, **스자좡시**(石家莊市)의 관할하에 있습니다.
# - 정딩현은 역사적으로 중요한 군사적 요충지였으며, 조운을 기념하는 **조운묘**(趙雲廟)와 **조운기념관** 등이 위치해 있어 관광지로도 유명합니다.
#
# ### 참고:
# - 조운은 “나는 상당의 조자룡이다!”(吾乃常山趙子龍也!)라는 대사로 유명하며, 이는 그가 상당군 출신임을 강조하는 말입니다.
# - 정딩현은 조운의 고향으로서 지역 문화와 관광 자원으로 활용되고 있으며, 조운을 기리는 축제나 행사도 열립니다.
#
# ✅ 따라서, **조운의 고향은 현재 중국 허베이성 정딩현**입니다.
# ChatResponse(model='qwen3-vl:235b-instruct-cloud', created_at='2025-11-06T04:56:10.923501533Z', done=True, done_reason='stop', total_duration=4484191003, load_duration=None, prompt_eval_count=29, prompt_eval_duration=None, eval_count=369, eval_duration=None, message=Message(role='assistant', content='조운(趙雲, 조운)의 고향은 **현재 중국 허베이성 정딩현**(河北省 正定縣)입니다.\n\n### 상세 설명:\n\n- **조운**은 삼국지 시대 촉한의 유명한 장군으로, ‘자룡(子龍)’이라는 자를 쓰며, 충성과 용맹, 정의로운 성격으로 유명합니다.\n- 그의 고향은 **상당군 진정현**(常山郡 真定縣)으로, **한나라 시대**에 속한 지역입니다.\n- 이 지역은 현재 **중국 허베이성 정딩현**(正定縣, Hebei Province, Zhengding County)으로, **스자좡시**(石家莊市)의 관할하에 있습니다.\n- 정딩현은 역사적으로 중요한 군사적 요충지였으며, 조운을 기념하는 **조운묘**(趙雲廟)와 **조운기념관** 등이 위치해 있어 관광지로도 유명합니다.\n\n### 참고:\n- 조운은 “나는 상당의 조자룡이다!”(吾乃常山趙子龍也!)라는 대사로 유명하며, 이는 그가 상당군 출신임을 강조하는 말입니다.\n- 정딩현은 조운의 고향으로서 지역 문화와 관광 자원으로 활용되고 있으며, 조운을 기리는 축제나 행사도 열립니다.\n\n✅ 따라서, **조운의 고향은 현재 중국 허베이성 정딩현**입니다.', thinking=None, images=None, tool_name=None, tool_calls=None))
