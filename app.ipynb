# %%
# !uv add ollama

# %%
from ollama import chat, ChatResponse
import os

model_id = 'qwen3-vl:235b-instruct-cloud'
api_key = 'f306bbcebc3642f39e43744afa3c13b7.aH1Gn9Al9C-LvxKczozDTU8s'

os.environ['OLLAMA_API_KEY'] = api_key
os.environ.setdefault('OLLAMA_HOST', 'https://ollama.com/api')
print('OLLAMA_HOST=', os.environ['OLLAMA_HOST'])

try:
    response: ChatResponse = chat(
        model=model_id,
        messages=[{'role': 'user', 'content': '삼국지 인물중 조운의 고향은 현재 중국의 어디인가?'}],
        options={'temperature': 0.0},
    )
    print('Client response:', response.message.content)
except Exception as e:
    print('Client call failed:', e)

# %%
import ollama_generate
import os

OLLAMA_HOST = os.getenv('OLLAMA_HOST', 'https://ollama.com/api')
os.environ.setdefault('OLLAMA_HOST', 'https://ollama.com/api')
OLLAMA_MODEL_ID = os.getenv("OLLAMA_MODEL_ID", "qwen3-vl:235b-instruct-cloud")
OLLAMA_API_KEY = os.getenv("OLLAMA_API_KEY", "f306bbcebc3642f39e43744afa3c13b7.aH1Gn9Al9C-LvxKczozDTU8s")

print('OLLAMA_HOST=', OLLAMA_HOST)

pred_dir = os.path.abspath(os.path.join('captcha_data', 'gov24', '1', 'images', 'pred'))
if not os.path.isdir(pred_dir):
    raise FileNotFoundError(f'Prediction directory not found: {pred_dir}')
files = [f for f in os.listdir(pred_dir) if os.path.isfile(os.path.join(pred_dir, f))]
if not files:
    raise FileNotFoundError(f'No files found in prediction directory: {pred_dir}')
image_path = os.path.join(pred_dir, files[0])
with open(image_path, 'rb') as fh:
    sample_bytes = fh.read()
print('Using file for test:', image_path)

result = ollama_generate.ocr_image(image_path=image_path)
file_name = os.path.basename(image_path)
# print('file_name  :', file_name)
# print('ocr_result :', result)
result
# Out:
# OLLAMA_HOST= https://ollama.com/api
# Using file for test: /home/hyper/project/hyper-captcha-resolver/captcha_data/gov24/1/images/pred/680179.png
# image_path: /home/hyper/project/hyper-captcha-resolver/captcha_data/gov24/1/images/pred/680179.png
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[1], line 22
#      19     sample_bytes = fh.read()
#      20 print('Using file for test:', image_path)
# ---> 22 result = ollama_generate.ocr_image(image_path=image_path)
#      23 file_name = os.path.basename(image_path)
#      24 # print('file_name  :', file_name)
#      25 # print('ocr_result :', result)
#
# File ~/project/hyper-captcha-resolver/ollama_generate.py:58, in ocr_image(image_path, model_id, api_key)
#      39 start_time = time.perf_counter()
#      41 messages=[{
#      42 'role': 'user',
#      43 'content': """
#    (...)     55     }""",
#      56 'images': [image_path]}]
# ---> 58 response: ChatResponse = chat(
#      59     model=model_id,
#      60     messages=messages,
#      61     options={'temperature': 0.0},
#      62 )
#      64 elapsed_ms = int(round((time.perf_counter() - start_time) * 1000))
#      66 result = response.message.content
#
# File ~/project/hyper-captcha-resolver/.venv/lib/python3.12/site-packages/ollama/_client.py:351, in Client.chat(self, model, messages, tools, stream, think, format, options, keep_alive)
#     306 def chat(
#     307   self,
#     308   model: str = '',
#    (...)    316   keep_alive: Optional[Union[float, str]] = None,
#     317 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     318   """
#     319   Create a chat response using the requested model.
#     320
#    (...)    349   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     350   """
# --> 351   return self._request(
#     352     ChatResponse,
#     353     'POST',
#     354     '/api/chat',
#     355     json=ChatRequest(
#     356       model=model,
#     357       messages=list(_copy_messages(messages)),
#     358       tools=list(_copy_tools(tools)),
#     359       stream=stream,
#     360       think=think,
#     361       format=format,
#     362       options=options,
#     363       keep_alive=keep_alive,
#     364     ).model_dump(exclude_none=True),
#     365     stream=stream,
#     366   )
#
# File ~/project/hyper-captcha-resolver/.venv/lib/python3.12/site-packages/ollama/_client.py:189, in Client._request(self, cls, stream, *args, **kwargs)
#     185         yield cls(**part)
#     187   return inner()
# --> 189 return cls(**self._request_raw(*args, **kwargs).json())
#
# File ~/project/hyper-captcha-resolver/.venv/lib/python3.12/site-packages/ollama/_client.py:135, in Client._request_raw(self, *args, **kwargs)
#     133   raise ResponseError(e.response.text, e.response.status_code) from None
#     134 except httpx.ConnectError:
# --> 135   raise ConnectionError(CONNECTION_ERROR_MESSAGE) from None
#
# ConnectionError: Failed to connect to Ollama. Please check that Ollama is downloaded, running and accessible. https://ollama.com/download

# %%
import ollama_generate
import os

model_id = 'qwen3-vl:235b-instruct-cloud'
api_key = 'f306bbcebc3642f39e43744afa3c13b7.aH1Gn9Al9C-LvxKczozDTU8s'

os.environ['OLLAMA_API_KEY'] = api_key
os.environ.setdefault('OLLAMA_HOST', 'https://ollama.com/api')
print('OLLAMA_HOST=', os.environ['OLLAMA_HOST'])

message = '삼국지 인물중 조운의 고향은 현재 중국의 어디인가?'
result = ollama_generate.cloud_chat(message=message, model_id=model_id, api_key=api_key)
print('Q : ', message)
content = result.message.content
print('A : ', content)

result
# Out:
# OLLAMA_HOST= https://ollama.com/api
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 12
#       9 print('OLLAMA_HOST=', os.environ['OLLAMA_HOST'])
#      11 message = '삼국지 인물중 조운의 고향은 현재 중국의 어디인가?'
# ---> 12 result = ollama_generate.cloud_chat(message=message, model_id=model_id, api_key=api_key)
#      13 print('Q : ', message)
#      14 content = result.message.content
#
# AttributeError: module 'ollama_generate' has no attribute 'cloud_chat'
